# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Using logical and comparison operators

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning Objectives
#
# - Understand the concept of logic and comparison operators in SQL.
# - Learn how to use the WHERE clause to filter data based on specific conditions.
# - Understand the use of IN, BETWEEN, and other SQL operators to streamline queries.

# %% [markdown]
# ## Overview
#
# In this notebook, we will explore the use of logic and comparison operators in SQL to filter and extract specific data from a dataset. These operators are essential tools in SQL that allow us to narrow down our data based on certain conditions.
#
# We will be working with the `united_nations.Access_to_Basic_Services` table, which contains information about different countries, their GDP, access to basic services, and more.

# %% [markdown]
# ### Connecting to our MySQL database
#
# Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# load and activate the SQL extension to allows us to execute SQL in a Jupyter notebook

# %load_ext sql

# %%
# establish a connection to the local database using the '%sql' magic command,
# replace 'password' with our connection password and `db_name` with our database name

# %sql mysql+pymysql://root:12122001UPi@localhost:3306/united_nations
# Out:
# Connecting and switching to connection 'mysql+pymysql://root:***@localhost:3306/united_nations'

# %%
# %config SqlMagic.displaylimit = None
# Out:
# displaylimit: Value None will be treated as 0 (no limit)

# %% [markdown]
# ## Exercise
#
# ### Task 1: Basic Filtering with Comparison Operators
#
# You will be working with the `united_nations.Access_to_Basic_Services` table.
# The columns to `SELECT` include
# - `Country_name`
# - `Time_period`
# - `Pct_managed_drinking_water_services`
# - `Pct_managed_sanitation_services`
# - `Est_population_in_millions`
# - and `Est_gdp_in_billions`
#
#
# Use the `WHERE` clause to filter out records of specific countries:
# - `Nigeria`,
# - `Ethiopia`,
# - `Congo`,
# - `Egypt`,
# - `Tanzania`,
# - `Kenya`,
# - and `South Africa`
# - for the time period between `2019` and `2020`.
# Utilize the `OR` operator to include multiple countries in your filter.

# %%
# %%sql
# SELECT
# Country_name,
# Time_period,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Country_name IN (
# 'Nigeria',
# 'Ethiopia',
# 'Congo',
# 'Egypt',
# 'Tanzania',
# 'Kenya',
# 'South Africa')
# AND Time_period BETWEEN 2019 AND 2020;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/united_nations'
# 12 rows affected.
# +--------------+-------------+---------------------------------+----------------------------+---------------------+
# | Country_name | Time_period | Pct_managed_sanitation_services | Est_population_in_millions | Est_gdp_in_billions |
# +--------------+-------------+---------------------------------+----------------------------+---------------------+
# |    Egypt     |     2019    |              97.00              |            None            |         None        |
# |    Egypt     |     2020    |              97.67              |            None            |         None        |
# |   Ethiopia   |     2019    |              11.67              |         114.120594         |        95.91        |
# |   Ethiopia   |     2020    |              11.67              |         117.190911         |        107.66       |
# |    Kenya     |     2019    |              33.33              |         50.951450          |        100.38       |
# |    Kenya     |     2020    |              33.67              |         51.985780          |        100.67       |
# |    Congo     |     2019    |              17.67              |            None            |         None        |
# |    Congo     |     2020    |              17.67              |            None            |         None        |
# | South Africa |     2019    |              78.00              |         58.087055          |        388.53       |
# | South Africa |     2020    |              78.67              |         58.801927          |        337.62       |
# |   Nigeria    |     2019    |              41.67              |         203.304492         |        448.12       |
# |   Nigeria    |     2020    |              42.67              |         208.327405         |        432.20       |
# +--------------+-------------+---------------------------------+----------------------------+---------------------+

# %% [markdown]
# ### Task 2: Streamlining with the IN Operator
#
# Building on the first task, you might have noticed that using multiple `OR` operators can make the query lengthy and a bit complicated. The 'IN' operator offers a more efficient way to achieve the same result.
# The `IN` operator allows you to specify multiple values in a `WHERE` clause, making the query more concise.
# Try to retrieve data for the same list of countries for the same time range, but this time, use the `IN` operator to simplify your query.

# %%
# %%sql
# SHOW TABLES;
#
# SELECT
# Country_name,
# Time_period,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions FROM access_to_basic_services
# WHERE Time_period IN (2019, 2020);
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/united_nations'
# 2 rows affected.
# 334 rows affected.
# +---------------------------------------+-------------+---------------------------------+----------------------------+---------------------+
# |              Country_name             | Time_period | Pct_managed_sanitation_services | Est_population_in_millions | Est_gdp_in_billions |
# +---------------------------------------+-------------+---------------------------------+----------------------------+---------------------+
# |               Kazakhstan              |     2019    |              98.00              |         18.513673          |        181.67       |
# |               Kazakhstan              |     2020    |              98.00              |         18.755666          |        171.08       |
# |               Kyrgyzstan              |     2019    |              97.33              |            None            |         None        |
# |               Kyrgyzstan              |     2020    |              97.67              |            None            |         None        |
# |               Tajikistan              |     2019    |              96.33              |          9.337003          |         8.30        |
# |               Tajikistan              |     2020    |              96.33              |          9.543207          |         8.13        |
# |              Turkmenistan             |     2019    |              99.33              |          6.158420          |        45.23        |
# |              Turkmenistan             |     2020    |              99.33              |          6.250438          |         None        |
# |               Uzbekistan              |     2019    |              100.00             |         33.580350          |        59.91        |
# |               Uzbekistan              |     2020    |              100.00             |         34.232050          |        59.89        |
# |              Afghanistan              |     2019    |              52.33              |         37.769499          |        18.90        |
# |              Afghanistan              |     2020    |              54.00              |         38.972230          |        20.14        |
# |               Bangladesh              |     2019    |              52.67              |         165.516222         |        351.24       |
# |               Bangladesh              |     2020    |              54.00              |         167.420951         |        373.90       |
# |                 Bhutan                |     2019    |              75.00              |          0.767459          |         2.54        |
# |                 Bhutan                |     2020    |              76.67              |          0.772506          |         2.33        |
# |                 India                 |     2019    |              69.67              |        1383.112050         |       2831.55       |
# |                 India                 |     2020    |              72.33              |        1396.387127         |       2667.69       |
# |       Iran (Islamic Republic of)      |     2019    |              88.33              |            None            |         None        |
# |       Iran (Islamic Republic of)      |     2020    |              88.33              |            None            |         None        |
# |                Maldives               |     2019    |              98.33              |          0.504508          |         5.61        |
# |                Maldives               |     2020    |              99.33              |          0.514438          |         3.75        |
# |                 Nepal                 |     2019    |              73.33              |         28.832496          |        34.19        |
# |                 Nepal                 |     2020    |              76.67              |         29.348627          |        33.43        |
# |                Pakistan               |     2019    |              68.67              |         223.293280         |        320.91       |
# |                Pakistan               |     2020    |              70.00              |         227.196741         |        300.43       |
# |               Sri Lanka               |     2019    |              93.67              |         21.803000          |        89.01        |
# |               Sri Lanka               |     2020    |              93.67              |         21.919000          |        85.35        |
# |                 China                 |     2019    |              90.33              |        1407.745000         |       14279.94      |
# |                 China                 |     2020    |              91.67              |        1411.100000         |       14687.67      |
# | Democratic People's Republic of Korea |     2019    |              83.33              |            None            |         None        |
# | Democratic People's Republic of Korea |     2020    |              83.33              |            None            |         None        |
# |                 Japan                 |     2019    |              100.00             |         126.633000         |       5123.32       |
# |                 Japan                 |     2020    |              100.00             |         126.261000         |       5040.11       |
# |                Mongolia               |     2019    |              63.67              |          3.232430          |        14.21        |
# |                Mongolia               |     2020    |              65.00              |          3.294335          |        13.31        |
# |           Republic of Korea           |     2019    |              100.00             |            None            |         None        |
# |           Republic of Korea           |     2020    |              100.00             |            None            |         None        |
# |           Brunei Darussalam           |     2019    |               None              |          0.438048          |        13.47        |
# |           Brunei Darussalam           |     2020    |               None              |          0.441725          |        12.01        |
# |                Cambodia               |     2019    |              71.67              |         16.207746          |        27.09        |
# |                Cambodia               |     2020    |              74.33              |         16.396860          |        25.87        |
# |               Indonesia               |     2019    |              83.33              |         269.582878         |       1119.10       |
# |               Indonesia               |     2020    |              86.00              |         271.857970         |       1058.69       |
# |    Lao People's Democratic Republic   |     2019    |              82.00              |            None            |         None        |
# |    Lao People's Democratic Republic   |     2020    |              82.00              |            None            |         None        |
# |                Malaysia               |     2019    |              100.00             |         32.804020          |        365.18       |
# |                Malaysia               |     2020    |              100.00             |         33.199993          |        337.34       |
# |                Myanmar                |     2019    |              74.00              |         53.040212          |        68.70        |
# |                Myanmar                |     2020    |              74.67              |         53.423198          |        78.93        |
# |              Philippines              |     2019    |              81.00              |         110.380804         |        376.82       |
# |              Philippines              |     2020    |              82.00              |         112.190977         |        361.75       |
# |               Singapore               |     2019    |              100.00             |          5.703569          |        375.47       |
# |               Singapore               |     2020    |              100.00             |          5.685807          |        345.30       |
# |                Thailand               |     2019    |              98.33              |         71.307763          |        544.08       |
# |                Thailand               |     2020    |              98.67              |         71.475664          |        499.68       |
# |              Timor-Leste              |     2019    |              59.00              |          1.280438          |         2.03        |
# |              Timor-Leste              |     2020    |              60.00              |          1.299995          |         2.16        |
# |                Viet Nam               |     2019    |              89.00              |            None            |         None        |
# |                Viet Nam               |     2020    |              90.00              |            None            |         None        |
# |                Bermuda                |     2019    |              100.00             |          0.063911          |         7.42        |
# |                Bermuda                |     2020    |              100.00             |          0.063893          |         6.89        |
# |                 Canada                |     2019    |              99.00              |         37.601230          |       1742.02       |
# |                 Canada                |     2020    |              99.00              |         38.037204          |       1645.42       |
# |               Greenland               |     2019    |              100.00             |          0.056225          |         2.99        |
# |               Greenland               |     2020    |              100.00             |          0.056367          |         3.08        |
# |       Saint Pierre and Miquelon       |     2019    |              100.00             |            None            |         None        |
# |       Saint Pierre and Miquelon       |     2020    |              100.00             |            None            |         None        |
# |        United States of America       |     2019    |              99.67              |            None            |         None        |
# |        United States of America       |     2020    |              99.67              |            None            |         None        |
# |                Bahamas                |     2019    |              95.00              |            None            |         None        |
# |                Barbados               |     2019    |              98.00              |          0.280180          |         5.32        |
# |                Barbados               |     2020    |              98.00              |          0.280693          |         4.67        |
# |         British Virgin Islands        |     2019    |               None              |          0.030610          |         None        |
# |         British Virgin Islands        |     2020    |               None              |          0.030910          |         None        |
# |                  Cuba                 |     2019    |              90.00              |         11.316697          |        103.43       |
# |                  Cuba                 |     2020    |              90.00              |         11.300698          |        107.35       |
# |           Dominican Republic          |     2019    |              84.33              |         10.881882          |        88.94        |
# |           Dominican Republic          |     2020    |              84.33              |         10.999664          |        78.84        |
# |               Guadeloupe              |     2019    |              100.00             |            None            |         None        |
# |               Guadeloupe              |     2020    |              100.00             |            None            |         None        |
# |                 Haiti                 |     2019    |              36.00              |         11.160438          |        14.79        |
# |                 Haiti                 |     2020    |              36.00              |         11.306801          |        14.51        |
# |                Jamaica                |     2019    |              87.00              |          2.813773          |        15.83        |
# |                Jamaica                |     2020    |              87.00              |          2.820436          |        13.81        |
# |               Martinique              |     2019    |              100.00             |            None            |         None        |
# |               Martinique              |     2020    |              100.00             |            None            |         None        |
# |               Montserrat              |     2019    |              89.00              |            None            |         None        |
# |               Montserrat              |     2020    |              89.00              |            None            |         None        |
# |              Puerto Rico              |     2019    |              100.00             |          3.193694          |        105.13       |
# |              Puerto Rico              |     2020    |              100.00             |          3.281538          |        103.02       |
# |            Saint Barthélemy           |     2019    |              100.00             |            None            |         None        |
# |            Saint Barthélemy           |     2020    |              100.00             |            None            |         None        |
# |              Saint Lucia              |     2019    |              82.00              |            None            |         None        |
# |              Saint Lucia              |     2020    |              82.00              |            None            |         None        |
# |       Saint Martin (French Part)      |     2019    |              100.00             |            None            |         None        |
# |       Saint Martin (French Part)      |     2020    |              100.00             |            None            |         None        |
# |          Trinidad and Tobago          |     2019    |              94.00              |          1.519955          |        23.85        |
# |          Trinidad and Tobago          |     2020    |              94.00              |          1.518147          |        21.06        |
# |      United States Virgin Islands     |     2019    |              99.00              |            None            |         None        |
# |      United States Virgin Islands     |     2020    |              99.00              |            None            |         None        |
# |                 Belize                |     2019    |              88.67              |          0.389095          |         2.42        |
# |                 Belize                |     2020    |              88.67              |          0.394921          |         2.08        |
# |               Costa Rica              |     2019    |              97.33              |          5.084532          |        64.42        |
# |               Costa Rica              |     2020    |              97.67              |          5.123105          |        62.16        |
# |              El Salvador              |     2019    |              80.33              |          6.280217          |        26.88        |
# |              El Salvador              |     2020    |              79.67              |          6.292731          |        24.56        |
# |               Guatemala               |     2019    |              67.67              |         16.604026          |        77.17        |
# |               Guatemala               |     2020    |              67.67              |         16.858333          |        77.63        |
# |                Honduras               |     2019    |              82.67              |          9.958829          |        25.09        |
# |                Honduras               |     2020    |              83.33              |         10.121763          |        23.83        |
# |                 Mexico                |     2019    |              90.00              |         125.085311         |       1269.01       |
# |                 Mexico                |     2020    |              90.67              |         125.998302         |       1090.52       |
# |               Nicaragua               |     2019    |              71.67              |          6.663924          |        12.60        |
# |               Nicaragua               |     2020    |              71.67              |          6.755895          |        12.59        |
# |                 Panama                |     2019    |              79.67              |          4.232532          |        66.98        |
# |                 Panama                |     2020    |              81.00              |          4.294396          |        53.98        |
# |               Argentina               |     2019    |              98.00              |         44.938712          |        447.75       |
# |               Argentina               |     2020    |              99.00              |         45.376763          |        385.54       |
# |    Bolivia (Plurinational State of)   |     2019    |              59.67              |            None            |         None        |
# |    Bolivia (Plurinational State of)   |     2020    |              61.67              |            None            |         None        |
# |                 Brazil                |     2019    |              81.67              |         211.782878         |       1873.27       |
# |                 Brazil                |     2020    |              82.33              |         213.196304         |       1448.56       |
# |                 Chile                 |     2019    |              100.00             |         19.039485          |        278.58       |
# |                 Chile                 |     2020    |              100.00             |         19.300315          |        252.73       |
# |                Colombia               |     2019    |              90.33              |         50.187406          |        323.11       |
# |                Colombia               |     2020    |              91.33              |         50.930662          |        270.30       |
# |                Ecuador                |     2019    |              90.00              |         17.343740          |        108.11       |
# |                Ecuador                |     2020    |              91.33              |         17.588595          |        99.29        |
# |      Falkland Islands (Malvinas)      |     2019    |              100.00             |            None            |         None        |
# |      Falkland Islands (Malvinas)      |     2020    |              100.00             |            None            |         None        |
# |             French Guiana             |     2019    |              92.00              |            None            |         None        |
# |             French Guiana             |     2020    |              92.00              |            None            |         None        |
# |                 Guyana                |     2019    |              87.33              |          0.798753          |         5.17        |
# |                 Guyana                |     2020    |              87.33              |          0.797202          |         5.47        |
# |                Paraguay               |     2019    |              91.33              |          6.530026          |        37.93        |
# |                Paraguay               |     2020    |              92.00              |          6.618695          |        35.43        |
# |                  Peru                 |     2019    |              73.33              |         32.824861          |        228.32       |
# |                  Peru                 |     2020    |              74.33              |         33.304756          |        201.71       |
# |                Suriname               |     2019    |              87.67              |          0.600301          |         4.02        |
# |                Suriname               |     2020    |              88.67              |          0.607065          |         2.91        |
# |                Uruguay                |     2019    |              98.00              |          3.428409          |        61.23        |
# |                Uruguay                |     2020    |              98.33              |          3.429086          |        53.56        |
# |   Venezuela (Bolivarian Republic of)  |     2019    |              96.00              |            None            |         None        |
# |   Venezuela (Bolivarian Republic of)  |     2020    |              96.00              |            None            |         None        |
# |                Algeria                |     2019    |              84.67              |         42.705368          |        171.77       |
# |                Algeria                |     2020    |              84.33              |         43.451666          |        145.01       |
# |                 Egypt                 |     2019    |              97.00              |            None            |         None        |
# |                 Egypt                 |     2020    |              97.67              |            None            |         None        |
# |                 Libya                 |     2019    |              92.00              |          6.569088          |        69.25        |
# |                 Libya                 |     2020    |              92.00              |          6.653942          |        50.36        |
# |                Morocco                |     2019    |              84.00              |         36.304408          |        128.92       |
# |                Morocco                |     2020    |              84.67              |         36.688772          |        121.35       |
# |                 Sudan                 |     2019    |              40.33              |         43.232093          |        32.34        |
# |                 Sudan                 |     2020    |              40.33              |         44.440486          |        27.03        |
# |                Tunisia                |     2019    |              95.67              |         12.049314          |        41.91        |
# |                Tunisia                |     2020    |              97.33              |         12.161723          |        42.54        |
# |                Armenia                |     2019    |              92.33              |          2.820602          |        13.62        |
# |                Armenia                |     2020    |              92.33              |          2.805608          |        12.64        |
# |               Azerbaijan              |     2019    |              96.00              |         10.024283          |        48.17        |
# |               Azerbaijan              |     2020    |              96.00              |         10.093121          |        42.69        |
# |                Bahrain                |     2019    |              100.00             |          1.494188          |        38.65        |
# |                Bahrain                |     2020    |              100.00             |          1.477469          |        34.72        |
# |                 Cyprus                |     2019    |              99.33              |          1.228836          |        25.94        |
# |                 Cyprus                |     2020    |              99.33              |          1.237537          |        25.01        |
# |                Georgia                |     2019    |              84.67              |          3.720161          |        17.47        |
# |                Georgia                |     2020    |              84.33              |          3.722716          |        15.84        |
# |                  Iraq                 |     2019    |              99.33              |         41.563520          |        233.64       |
# |                  Iraq                 |     2020    |              100.00             |         42.556984          |        184.37       |
# |                 Israel                |     2019    |              99.67              |          9.054000          |        402.47       |
# |                 Israel                |     2020    |              99.67              |          9.215100          |        413.27       |
# |                 Jordan                |     2019    |              96.33              |         10.698683          |        44.99        |
# |                 Jordan                |     2020    |              96.33              |         10.928721          |        44.18        |
# |                 Kuwait                |     2019    |              100.00             |          4.441100          |        136.20       |
# |                 Kuwait                |     2020    |              100.00             |          4.360444          |        105.96       |
# |                Lebanon                |     2019    |              99.00              |          5.781907          |        51.95        |
# |                Lebanon                |     2020    |              99.00              |          5.662923          |        31.71        |
# |                  Oman                 |     2019    |              99.00              |          4.602768          |        88.06        |
# |                  Oman                 |     2020    |              99.00              |          4.543399          |        75.91        |
# |                 Qatar                 |     2019    |              100.00             |          2.807235          |        175.84       |
# |                 Qatar                 |     2020    |              100.00             |          2.760385          |        144.41       |
# |              Saudi Arabia             |     2019    |              100.00             |         35.827362          |        803.62       |
# |              Saudi Arabia             |     2020    |              100.00             |         35.997107          |        703.37       |
# |           State of Palestine          |     2019    |              97.67              |            None            |         None        |
# |           State of Palestine          |     2020    |              98.67              |            None            |         None        |
# |          Syrian Arab Republic         |     2019    |              90.00              |         20.098251          |        22.44        |
# |          Syrian Arab Republic         |     2020    |              90.00              |         20.772595          |        11.08        |
# |                Türkiye                |     2019    |              98.33              |            None            |         None        |
# |                Türkiye                |     2020    |              98.67              |            None            |         None        |
# |          United Arab Emirates         |     2019    |              99.00              |          9.211657          |        417.99       |
# |          United Arab Emirates         |     2020    |              99.00              |          9.287289          |        349.47       |
# |                 Yemen                 |     2019    |              57.00              |            None            |         None        |
# |                 Yemen                 |     2020    |              57.33              |            None            |         None        |
# |               Australia               |     2019    |              100.00             |         25.340217          |       1392.23       |
# |               Australia               |     2020    |              100.00             |         25.655289          |       1326.90       |
# |              New Zealand              |     2019    |              100.00             |          4.979200          |        213.43       |
# |              New Zealand              |     2020    |              100.00             |          5.090200          |        211.73       |
# |                  Fiji                 |     2019    |              99.00              |          0.918465          |         5.48        |
# |                  Fiji                 |     2020    |              99.00              |          0.920422          |         4.48        |
# |             New Caledonia             |     2019    |              100.00             |          0.271230          |         9.44        |
# |             New Caledonia             |     2020    |              100.00             |          0.271130          |         9.44        |
# |            Papua New Guinea           |     2019    |              27.67              |          9.542486          |        24.75        |
# |            Papua New Guinea           |     2020    |              27.67              |          9.749640          |        23.85        |
# |            Solomon Islands            |     2019    |              44.33              |          0.674993          |         1.62        |
# |            Solomon Islands            |     2020    |              44.67              |          0.691191          |         1.54        |
# |                Vanuatu                |     2019    |              55.67              |          0.304404          |         0.94        |
# |                Vanuatu                |     2020    |              55.67              |          0.311685          |         0.90        |
# |                  Guam                 |     2019    |               None              |          0.168624          |         6.37        |
# |                  Guam                 |     2020    |               None              |          0.169231          |         5.89        |
# |                Kiribati               |     2019    |              44.67              |          0.124241          |         0.18        |
# |                Kiribati               |     2020    |              45.33              |          0.126463          |         0.18        |
# |            Marshall Islands           |     2019    |              78.00              |          0.044728          |         0.23        |
# |            Marshall Islands           |     2020    |              78.00              |          0.043413          |         0.24        |
# |    Micronesia (Federated States of)   |     2019    |              88.00              |            None            |         None        |
# |                 Nauru                 |     2019    |               None              |          0.012132          |         0.12        |
# |                 Nauru                 |     2020    |               None              |          0.012315          |         0.11        |
# |        Northern Mariana Islands       |     2019    |              79.00              |          0.049858          |         1.18        |
# |        Northern Mariana Islands       |     2020    |              79.00              |          0.049587          |         None        |
# |                 Palau                 |     2019    |              99.67              |          0.017916          |         0.28        |
# |                 Palau                 |     2020    |              99.67              |          0.017972          |         0.25        |
# |             American Samoa            |     2019    |              54.00              |          0.047321          |         0.65        |
# |             American Samoa            |     2020    |              54.00              |          0.046189          |         0.72        |
# |              Cook Islands             |     2019    |              99.00              |            None            |         None        |
# |              Cook Islands             |     2020    |              99.00              |            None            |         None        |
# |            French Polynesia           |     2019    |              97.00              |          0.299717          |         6.00        |
# |            French Polynesia           |     2020    |              97.00              |          0.301920          |         5.71        |
# |                  Niue                 |     2019    |              96.00              |            None            |         None        |
# |                  Niue                 |     2020    |              96.00              |            None            |         None        |
# |                 Samoa                 |     2019    |              96.33              |          0.211905          |         0.91        |
# |                 Samoa                 |     2020    |              96.33              |          0.214929          |         0.87        |
# |                Tokelau                |     2019    |              97.00              |            None            |         None        |
# |                Tokelau                |     2020    |              97.00              |            None            |         None        |
# |                 Tonga                 |     2019    |              93.67              |          0.104951          |         0.51        |
# |                 Tonga                 |     2020    |              93.33              |          0.105254          |         0.48        |
# |                 Tuvalu                |     2019    |               None              |          0.010956          |         0.05        |
# |                 Tuvalu                |     2020    |               None              |          0.011069          |         0.06        |
# |       Wallis and Futuna Islands       |     2019    |              93.00              |            None            |         None        |
# |       Wallis and Futuna Islands       |     2020    |              93.00              |            None            |         None        |
# |                Burundi                |     2019    |              44.33              |         11.874838          |         2.58        |
# |                Burundi                |     2020    |              44.33              |         12.220227          |         2.65        |
# |                Comoros                |     2019    |              37.67              |          0.790986          |         1.20        |
# |                Djibouti               |     2019    |              56.00              |          1.073994          |         3.09        |
# |                Djibouti               |     2020    |              56.00              |          1.090156          |         3.18        |
# |                Ethiopia               |     2019    |              11.67              |         114.120594         |        95.91        |
# |                Ethiopia               |     2020    |              11.67              |         117.190911         |        107.66       |
# |                 Kenya                 |     2019    |              33.33              |         50.951450          |        100.38       |
# |                 Kenya                 |     2020    |              33.67              |         51.985780          |        100.67       |
# |               Madagascar              |     2019    |              12.67              |         27.533134          |        14.10        |
# |               Madagascar              |     2020    |              13.00              |         28.225177          |        13.05        |
# |                 Malawi                |     2019    |              28.33              |         18.867337          |        11.03        |
# |                 Malawi                |     2020    |              28.67              |         19.377061          |        12.18        |
# |               Mauritius               |     2019    |              96.00              |          1.265711          |        14.44        |
# |               Mauritius               |     2020    |              96.00              |          1.265740          |        11.40        |
# |                Mayotte                |     2019    |              100.00             |            None            |         None        |
# |                Mayotte                |     2020    |              100.00             |            None            |         None        |
# |               Mozambique              |     2019    |              39.33              |         30.285595          |        15.39        |
# |               Mozambique              |     2020    |              40.33              |         31.178239          |        14.03        |
# |                 Rwanda                |     2019    |              64.00              |         12.835028          |        10.36        |
# |                 Rwanda                |     2020    |              64.00              |         13.146362          |        10.18        |
# |                Réunion                |     2019    |              100.00             |            None            |         None        |
# |                Réunion                |     2020    |              100.00             |            None            |         None        |
# |               Seychelles              |     2019    |              100.00             |          0.097625          |         1.68        |
# |                Somalia                |     2019    |              39.33              |         15.981300          |         6.49        |
# |                Somalia                |     2020    |              40.00              |         16.537016          |         6.88        |
# |              South Sudan              |     2019    |              22.33              |         10.447666          |         None        |
# |              South Sudan              |     2020    |              22.33              |         10.606227          |         None        |
# |                 Uganda                |     2019    |              21.67              |         42.949080          |        35.35        |
# |                 Uganda                |     2020    |              21.67              |         44.404611          |        37.60        |
# |      United Republic of Tanzania      |     2019    |              34.00              |            None            |         None        |
# |      United Republic of Tanzania      |     2020    |              34.00              |            None            |         None        |
# |                 Zambia                |     2019    |              32.00              |         18.380477          |        23.31        |
# |                 Zambia                |     2020    |              32.67              |         18.927715          |        18.11        |
# |                Zimbabwe               |     2019    |              37.00              |         15.354608          |        21.83        |
# |                Zimbabwe               |     2020    |              36.33              |         15.669666          |        21.51        |
# |                 Angola                |     2019    |              46.67              |         32.353588          |        69.31        |
# |                 Angola                |     2020    |              47.00              |         33.428486          |        53.62        |
# |                Cameroon               |     2019    |              42.33              |         25.782341          |        39.67        |
# |                Cameroon               |     2020    |              43.00              |         26.491087          |        40.77        |
# |        Central African Republic       |     2019    |              15.33              |          5.209324          |         2.22        |
# |        Central African Republic       |     2020    |              15.00              |          5.343020          |         2.33        |
# |                  Chad                 |     2019    |              18.33              |         16.126866          |        11.31        |
# |                  Chad                 |     2020    |              18.67              |         16.644701          |        10.72        |
# |                 Congo                 |     2019    |              17.67              |            None            |         None        |
# |                 Congo                 |     2020    |              17.67              |            None            |         None        |
# |    Democratic Republic of the Congo   |     2019    |              16.33              |            None            |         None        |
# |    Democratic Republic of the Congo   |     2020    |              15.33              |            None            |         None        |
# |                 Gabon                 |     2019    |              47.00              |          2.242785          |        16.87        |
# |                 Gabon                 |     2020    |              47.00              |          2.292573          |        15.31        |
# |         Sao Tome and Principe         |     2019    |              44.33              |          0.214599          |         0.43        |
# |         Sao Tome and Principe         |     2020    |              46.00              |          0.218641          |         0.47        |
# |                Botswana               |     2019    |              74.33              |          2.499702          |        16.70        |
# |                Botswana               |     2020    |              74.33              |          2.546402          |        14.93        |
# |                Eswatini               |     2019    |              61.33              |          1.169613          |         4.50        |
# |                Eswatini               |     2020    |              61.33              |          1.180655          |         3.98        |
# |                Lesotho                |     2019    |              47.67              |          2.225702          |         2.45        |
# |                Lesotho                |     2020    |              49.67              |          2.254100          |         2.23        |
# |                Namibia                |     2019    |              35.00              |          2.446644          |        12.54        |
# |                Namibia                |     2020    |              35.00              |          2.489098          |        10.58        |
# |              South Africa             |     2019    |              78.00              |         58.087055          |        388.53       |
# |              South Africa             |     2020    |              78.67              |         58.801927          |        337.62       |
# |                 Benin                 |     2019    |              17.00              |         12.290444          |        14.39        |
# |                 Benin                 |     2020    |              17.33              |         12.643123          |        15.65        |
# |              Burkina Faso             |     2019    |              25.00              |         20.951639          |        16.18        |
# |              Burkina Faso             |     2020    |              25.00              |         21.522626          |        17.93        |
# |               Cabo Verde              |     2019    |              76.00              |          0.577030          |         1.98        |
# |               Cabo Verde              |     2020    |              78.00              |          0.582640          |         1.70        |
# |             Côte d'Ivoire             |     2019    |              33.67              |            None            |         None        |
# |             Côte d'Ivoire             |     2020    |              34.67              |            None            |         None        |
# |                 Gambia                |     2019    |              44.33              |            None            |         None        |
# |                 Gambia                |     2020    |              44.33              |            None            |         None        |
# |                 Ghana                 |     2019    |              22.67              |         31.522290          |        68.34        |
# |                 Ghana                 |     2020    |              23.00              |         32.180401          |        70.04        |
# |                 Guinea                |     2019    |              30.67              |         12.877539          |        13.44        |
# |                 Guinea                |     2020    |              32.33              |         13.205153          |        14.18        |
# |             Guinea-Bissau             |     2019    |              18.33              |          1.970457          |         1.44        |
# |             Guinea-Bissau             |     2020    |              19.33              |          2.015828          |         1.43        |
# |                Liberia                |     2019    |              17.67              |          4.985289          |         3.32        |
# |                Liberia                |     2020    |              17.67              |          5.087584          |         3.04        |
# |                  Mali                 |     2019    |              44.67              |         20.567424          |        17.28        |
# |                  Mali                 |     2020    |              46.00              |         21.224040          |        17.47        |
# |               Mauritania              |     2019    |              47.67              |          4.383849          |         8.07        |
# |               Mauritania              |     2020    |              48.00              |          4.498604          |         8.41        |
# |                 Niger                 |     2019    |              23.67              |         23.443393          |        12.92        |
# |                 Niger                 |     2020    |              24.67              |         24.333639          |        13.74        |
# |                Nigeria                |     2019    |              41.67              |         203.304492         |        448.12       |
# |                Nigeria                |     2020    |              42.67              |         208.327405         |        432.20       |
# |              Saint Helena             |     2019    |              100.00             |            None            |         None        |
# |              Saint Helena             |     2020    |              100.00             |            None            |         None        |
# |                Senegal                |     2019    |              56.33              |         16.000781          |        23.40        |
# |                Senegal                |     2020    |              57.00              |         16.436120          |        24.49        |
# |              Sierra Leone             |     2019    |              17.00              |          8.046828          |         4.08        |
# |              Sierra Leone             |     2020    |              17.33              |          8.233970          |         4.06        |
# |                  Togo                 |     2019    |              19.67              |          8.243094          |         7.22        |
# |                  Togo                 |     2020    |              20.00              |          8.442580          |         7.57        |
# +---------------------------------------+-------------+---------------------------------+----------------------------+---------------------+

# %% [markdown]
# ### Task 3: Combining Multiple Conditions
#
# The `<=` operator is a comparison operator that checks if the value on the left is less than or equal to the value on the right. In this task, you'll use it to filter countries based on specific service percentages.
# You'll continue working with the `united_nations.Access_to_Basic_Services` table.
# The columns to be selected for this task are
# - `Region`,
# - `Country_name`,
# - `Time_period`,
# - `Pct_managed_drinking_water_services`,
# - `Pct_managed_sanitation_services`,
# - `Est_population_in_millions`, and
# - `Est_gdp_in_billions`.
#
# Your goal is to extract data for the year 2020, focusing on countries where less than or equal to 50% of the population has access to sanitation services. This will help identify countries with critical sanitation needs.
# By using the `<=` operator with the `Pct_managed_sanitation_services` column, you can filter out countries that exceed this threshold, leaving only those with the most pressing sanitation challenges.

# %%
# %%sql
# SHOW TABLES;
#
# SELECT
# Country_name,
# Time_period,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions FROM access_to_basic_services
# WHERE Time_period = 2020
# AND Pct_managed_sanitation_services <= 50;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/united_nations'
# 2 rows affected.
# 41 rows affected.
# +----------------------------------+-------------+---------------------------------+----------------------------+---------------------+
# |           Country_name           | Time_period | Pct_managed_sanitation_services | Est_population_in_millions | Est_gdp_in_billions |
# +----------------------------------+-------------+---------------------------------+----------------------------+---------------------+
# |              Haiti               |     2020    |              36.00              |         11.306801          |        14.51        |
# |              Sudan               |     2020    |              40.33              |         44.440486          |        27.03        |
# |         Papua New Guinea         |     2020    |              27.67              |          9.749640          |        23.85        |
# |         Solomon Islands          |     2020    |              44.67              |          0.691191          |         1.54        |
# |             Kiribati             |     2020    |              45.33              |          0.126463          |         0.18        |
# |             Burundi              |     2020    |              44.33              |         12.220227          |         2.65        |
# |             Ethiopia             |     2020    |              11.67              |         117.190911         |        107.66       |
# |              Kenya               |     2020    |              33.67              |         51.985780          |        100.67       |
# |            Madagascar            |     2020    |              13.00              |         28.225177          |        13.05        |
# |              Malawi              |     2020    |              28.67              |         19.377061          |        12.18        |
# |            Mozambique            |     2020    |              40.33              |         31.178239          |        14.03        |
# |             Somalia              |     2020    |              40.00              |         16.537016          |         6.88        |
# |           South Sudan            |     2020    |              22.33              |         10.606227          |         None        |
# |              Uganda              |     2020    |              21.67              |         44.404611          |        37.60        |
# |   United Republic of Tanzania    |     2020    |              34.00              |            None            |         None        |
# |              Zambia              |     2020    |              32.67              |         18.927715          |        18.11        |
# |             Zimbabwe             |     2020    |              36.33              |         15.669666          |        21.51        |
# |              Angola              |     2020    |              47.00              |         33.428486          |        53.62        |
# |             Cameroon             |     2020    |              43.00              |         26.491087          |        40.77        |
# |     Central African Republic     |     2020    |              15.00              |          5.343020          |         2.33        |
# |               Chad               |     2020    |              18.67              |         16.644701          |        10.72        |
# |              Congo               |     2020    |              17.67              |            None            |         None        |
# | Democratic Republic of the Congo |     2020    |              15.33              |            None            |         None        |
# |              Gabon               |     2020    |              47.00              |          2.292573          |        15.31        |
# |      Sao Tome and Principe       |     2020    |              46.00              |          0.218641          |         0.47        |
# |             Lesotho              |     2020    |              49.67              |          2.254100          |         2.23        |
# |             Namibia              |     2020    |              35.00              |          2.489098          |        10.58        |
# |              Benin               |     2020    |              17.33              |         12.643123          |        15.65        |
# |           Burkina Faso           |     2020    |              25.00              |         21.522626          |        17.93        |
# |          Côte d'Ivoire           |     2020    |              34.67              |            None            |         None        |
# |              Gambia              |     2020    |              44.33              |            None            |         None        |
# |              Ghana               |     2020    |              23.00              |         32.180401          |        70.04        |
# |              Guinea              |     2020    |              32.33              |         13.205153          |        14.18        |
# |          Guinea-Bissau           |     2020    |              19.33              |          2.015828          |         1.43        |
# |             Liberia              |     2020    |              17.67              |          5.087584          |         3.04        |
# |               Mali               |     2020    |              46.00              |         21.224040          |        17.47        |
# |            Mauritania            |     2020    |              48.00              |          4.498604          |         8.41        |
# |              Niger               |     2020    |              24.67              |         24.333639          |        13.74        |
# |             Nigeria              |     2020    |              42.67              |         208.327405         |        432.20       |
# |           Sierra Leone           |     2020    |              17.33              |          8.233970          |         4.06        |
# |               Togo               |     2020    |              20.00              |          8.442580          |         7.57        |
# +----------------------------------+-------------+---------------------------------+----------------------------+---------------------+

# %% [markdown]
# ## Solutions
#
# ### Task 1: Basic Filtering with Comparison Operators

# %%
# %%sql
# SELECT
# Country_name,
# Time_period,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# (Country_name = 'Nigeria'
# OR Country_name = 'Ethiopia'
# OR Country_name = 'Congo'
# OR Country_name = 'Egypt'
# OR Country_name = 'Tanzania'
# OR Country_name = 'Kenya'
# OR Country_name ='South Africa')
# AND Time_period BETWEEN 2019 AND 2020;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/united_nations'
# 12 rows affected.
# +--------------+-------------+---------------------------------+----------------------------+---------------------+
# | Country_name | Time_period | Pct_managed_sanitation_services | Est_population_in_millions | Est_gdp_in_billions |
# +--------------+-------------+---------------------------------+----------------------------+---------------------+
# |    Egypt     |     2019    |              97.00              |            None            |         None        |
# |    Egypt     |     2020    |              97.67              |            None            |         None        |
# |   Ethiopia   |     2019    |              11.67              |         114.120594         |        95.91        |
# |   Ethiopia   |     2020    |              11.67              |         117.190911         |        107.66       |
# |    Kenya     |     2019    |              33.33              |         50.951450          |        100.38       |
# |    Kenya     |     2020    |              33.67              |         51.985780          |        100.67       |
# |    Congo     |     2019    |              17.67              |            None            |         None        |
# |    Congo     |     2020    |              17.67              |            None            |         None        |
# | South Africa |     2019    |              78.00              |         58.087055          |        388.53       |
# | South Africa |     2020    |              78.67              |         58.801927          |        337.62       |
# |   Nigeria    |     2019    |              41.67              |         203.304492         |        448.12       |
# |   Nigeria    |     2020    |              42.67              |         208.327405         |        432.20       |
# +--------------+-------------+---------------------------------+----------------------------+---------------------+

# %% [markdown]
# ### Task 2: Streamlining with the IN Operator

# %%
# %%sql
# SELECT
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Country_name IN (
#         'Nigeria',
#         'Ethiopia' ,
#         'Congo',
#         'Egypt',
#         'Tanzania',
#         'Kenya',
#         'South Africa'
#  )
# AND Time_period BETWEEN 2019 AND 2020;

# %% [markdown]
# ### Task 3: Combining Multiple Conditions

# %%
# %%sql
# SELECT
# Region,
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Time_period = 2020
# AND Pct_managed_sanitation_services <= 50;

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
